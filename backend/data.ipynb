# %%
import pandas as pd
data = pd.read_csv('data.csv')
data.head()
# Out:
#           src_ip  src_port         dst_ip  dst_port proto service    duration  \
# 0   192.168.1.37      4444  192.168.1.193     49178   tcp       -  290.371539
# 1  192.168.1.193     49180   192.168.1.37      8080   tcp       -    0.000102
# 2  192.168.1.193     49180   192.168.1.37      8080   tcp       -    0.000148
# 3  192.168.1.193     49180   192.168.1.37      8080   tcp       -    0.000113
# 4  192.168.1.193     49180   192.168.1.37      8080   tcp       -    0.000130
#
#    src_bytes  dst_bytes conn_state  ...  http_response_body_len  \
# 0     101568       2592        OTH  ...                       0
# 1          0          0        REJ  ...                       0
# 2          0          0        REJ  ...                       0
# 3          0          0        REJ  ...                       0
# 4          0          0        REJ  ...                       0
#
#    http_status_code  http_user_agent  http_orig_mime_types  \
# ...

# %% [markdown]
# You are a senior Machine Learning and Cybersecurity engineer.
#
# I want to build a Multi-Tier Hybrid Intrusion Detection System (MTH-IDS) using my own dataset.
#
# The system must detect:
# 1. Known attacks (signature-based detection)
# 2. Unknown attacks (anomaly-based detection)
#
# The implementation must be done in Python using:
# - pandas
# - numpy
# - scikit-learn
# - imbalanced-learn
# - xgboost
# - matplotlib
# - seaborn
#
# The system architecture must follow these steps:
#
# --------------------------------
# 1. DATA PREPROCESSING
# --------------------------------
#
# Load my dataset from a CSV file.
#
# Steps:
# 1. Handle missing values
# 2. Encode categorical variables
# 3. Normalize numerical features using Z-score normalization
# 4. Split the data into features (X) and labels (y)
#
# Check if the dataset is imbalanced.
#
# If imbalanced:
# apply SMOTE oversampling.
#
# Use K-means sampling or clustering to reduce redundant samples if needed.
#
# --------------------------------
# 2. FEATURE ENGINEERING
# --------------------------------
#
# Perform feature selection using:
#
# - Information Gain (mutual information)
# - FCBF-like filtering (remove low importance features)
#
# Then perform feature extraction using:
#
# Kernel PCA (KPCA)
#
# Optimize important hyperparameters using Bayesian Optimization (Gaussian Process).
#
# --------------------------------
# 3. SIGNATURE-BASED IDS (Known Attacks)
# --------------------------------
#
# Tier 1: Train supervised tree-based models:
#
# - Decision Tree
# - Random Forest
# - Extra Trees
# - XGBoost
#
# Evaluate each model using:
#
# - Accuracy
# - Precision
# - Recall
# - F1-score
# - Confusion Matrix
#
# --------------------------------
#
# Tier 2: Stacking Ensemble
#
# Combine all models using a stacking classifier.
#
# The stacking model will predict:
#
# Positive = Known attack
# Negative = Suspicious traffic
#
# If the traffic is classified as suspicious,
# send it to the anomaly-based detection system.
#
# --------------------------------
# 4. ANOMALY-BASED IDS (Unknown Attacks)
# --------------------------------
#
# Tier 3: Unsupervised detection
#
# Use K-means clustering to separate:
#
# - Normal behavior
# - Suspicious behavior
#
# Add cluster labeling.
#
# Calculate confidence score of predictions.
#
# If confidence > threshold (ex: 0.93):
# accept the prediction.
#
# --------------------------------
#
# Tier 4: Model Optimization
#
# Train two specialized classifiers:
#
# 1. classifier trained on False Positives
# 2. classifier trained on False Negatives
#
# These models improve detection accuracy.
#
# --------------------------------
# 5. FINAL OUTPUT
# --------------------------------
#
# The system must classify network traffic into:
#
# 1. Known attack (with attack type)
# 2. Unknown attack
# 3. Normal traffic
#
# --------------------------------
# 6. VISUALIZATION
# --------------------------------
#
# Generate the following plots:
#
# - Feature importance
# - Confusion matrix
# - Model comparison chart
# - Cluster visualization
#
# --------------------------------
# 7. CODE STRUCTURE
# --------------------------------
#
# Organize the project as:
#
# backend/
# │
# ├── data/
# │   └── dataset.csv
# │
# ├── preprocessing/
# │   └── preprocessing.py
# │
# ├── feature_engineering/
# │   └── features.py
# │
# ├── models/
# │   ├── signature_ids.py
# │   ├── anomaly_ids.py
# │   └── stacking_model.py
# │
# ├── evaluation/
# │   └── metrics.py
# │
# ├── main.py
# └── requirements.txt
#
# --------------------------------
#
# Write clean, modular, well-commented Python code.
#
# Also include:
# - training pipeline
# - prediction pipeline
# - model saving using joblib
